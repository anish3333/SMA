# %%
import sys
# !{sys.executable} -m pip install pandas ydata-profiling

# %%
import sys
# !{sys.executable} -m pip install ipywidgets

# %%
import sys
# !{sys.executable} -m pip list

# %%
import pandas as pd
from ydata_profiling import ProfileReport

# %%
file_path = "./data/stack-overflow-developer-survey-2025/survey_results_public.csv"

df = pd.read_csv(file_path)

df.shape

# %%
profile = ProfileReport(df, title="Stack Overflow 2025 Survey EDA", explorative=True)

profile

# %%
profile.to_file("stack_overflow_eda.html")
